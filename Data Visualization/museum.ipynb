# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
ls
# Out:
# Fifa.ipynb           fifa.csv             iris_versicolor.csv
# Untitled.ipynb       flight_delays.csv    iris_virginica.csv
# archive (7).zip      hello-seaborn.ipynb  line-charts.ipynb
# cancer.csv           ign_scores.csv       museum_visitors.csv
# cancer_b.csv         insurance.csv        spotify.csv
# cancer_m.csv         iris.csv             spotify.ipynb
# candy.csv            iris_setosa.csv

# %%
df_museum = pd.read_csv('museum_visitors.csv', index_col='Date', parse_dates=True)

# %%
df_museum.head()
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %%
plt.figure(figsize=(6,4))

plt.title("Museum Vistors in LA")

sns.lineplot(data= df_museum)

plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')
